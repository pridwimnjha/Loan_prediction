# %%
import pandas as pd
import seaborn as sns
import numpy as np
filepath="/content/train_ctrUa4K.csv"
df=pd.read_csv(filepath)

# %%
display(df)
df.shape
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.shape[0]
# Out:
# 614

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
sns.distplot(df['ApplicantIncome'])
# Out:
# <ipython-input-8-dd358a5a6987>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.boxplot(df['ApplicantIncome'])
# Out:
# <Axes: ylabel='ApplicantIncome'>

# %%
df.Education.value_counts(normalize=True)*100
# Out:
# Education
# Graduate        78.175896
# Not Graduate    21.824104
# Name: proportion, dtype: float64

# %%
df["total_income"]=df["ApplicantIncome"]+df["CoapplicantIncome"]
df.total_income
# Out:
# 0      5849.0
# 1      6091.0
# 2      3000.0
# 3      4941.0
# 4      6000.0
#         ...
# 609    2900.0
# 610    4106.0
# 611    8312.0
# 612    7583.0
# 613    4583.0
# Name: total_income, Length: 614, dtype: float64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  total_income
# count      564.000000    614.000000
# mean         0.842199   7024.705081
# std          0.364878   6458.663872
# min          0.000000   1442.000000
# 25%          1.000000   4166.000000
# 50%          1.000000   5416.500000
# 75%          1.000000   7521.750000
# max          1.000000  81000.000000

# %%
sns.distplot(df['total_income'])
# Out:
# <ipython-input-13-c7439a542ba6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_income'])
# <Axes: xlabel='total_income', ylabel='Density'>

# %%
sns.boxplot(df['total_income'])
# Out:
# <Axes: ylabel='total_income'>

# %%
sns.distplot(np.log(df['total_income']))
# Out:
# <ipython-input-15-df60583bf01e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['total_income']))
# <Axes: xlabel='total_income', ylabel='Density'>

# %%
sns.distplot(np.sqrt(df['total_income']))
# Out:
# <ipython-input-16-0451dfbda27d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.sqrt(df['total_income']))
# <Axes: xlabel='total_income', ylabel='Density'>

# %%
df["ti_log"]=np.log(df["total_income"])

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  total_income      ti_log
# count      564.000000    614.000000  614.000000
# mean         0.842199   7024.705081    8.669414
# std          0.364878   6458.663872    0.545102
# min          0.000000   1442.000000    7.273786
# 25%          1.000000   4166.000000    8.334712
# 50%          1.000000   5416.500000    8.597205
# 75%          1.000000   7521.750000    8.925549
# max          1.000000  81000.000000   11.302204

# %%
sns.boxplot(df['ti_log'])
# Out:
# <Axes: ylabel='ti_log'>

# %%
m=np.mean(df["ti_log"])
sd=np.std(df["ti_log"])
p99=np.percentile(df['ti_log'],99)
IQR=np.percentile(df['ti_log'],75)-np.percentile(df['ti_log'],25)
print(m,sd,p99,IQR)
# Out:
# 8.669413562902246 0.5446574620738445 10.530669145261063 0.590837815201553

# %%
print(f"mean+3*sd : {df.loc[df['ti_log'] > m+3*sd,'Loan_ID'].count()}")
# Out:
# mean+3*sd : 9

# %%
print(f"1.5*IQR: {df.loc[df['ti_log'] > 3*IQR, 'Loan_ID'].count()}")
# Out:
# 1.5*IQR: 614

# %%
print(f"p99: {df.loc[df['ti_log'] > p99, 'Loan_ID'].count()}")
# Out:
# p99: 7

# %%
df["ti_log"]=np.where(df["ti_log"]>p99,p99,df["ti_log"])

# %%
df["ti_log"].describe()
# Out:
# count    614.000000
# mean       8.666206
# std        0.532448
# min        7.273786
# 25%        8.334712
# 50%        8.597205
# 75%        8.925549
# max       10.530669
# Name: ti_log, dtype: float64

# %%
sns.distplot(df['ti_log'])
# Out:
# <ipython-input-26-279da1627336>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ti_log'])
# <Axes: xlabel='ti_log', ylabel='Density'>

# %%
m=np.mean(df.LoanAmount.dropna())
sd=np.std(df.LoanAmount.dropna())
p99=np.percentile(df.LoanAmount.dropna(),99)
iqr=np.percentile(df.LoanAmount.dropna(),75)-np.percentile(df.LoanAmount.dropna(),25)
print(m,sd,p99,iqr)
# Out:
# 146.41216216216216 85.51500809120331 496.3600000000001 68.0

# %%
df["LoanAmount"]=np.where(df["LoanAmount"]>p99,p99,df["LoanAmount"])
sns.distplot(df['LoanAmount'])
# Out:
# <ipython-input-28-69ab3777de56>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmount'])
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
sns.distplot(df['Loan_Amount_Term'])
# Out:
# <ipython-input-29-f274b1dfc1cc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Loan_Amount_Term'])
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
df.Loan_Amount_Term.value_counts(normalize=True)*100
# Out:
# Loan_Amount_Term
# 360.0    85.333333
# 180.0     7.333333
# 480.0     2.500000
# 300.0     2.166667
# 240.0     0.666667
# 84.0      0.666667
# 120.0     0.500000
# 60.0      0.333333
# 36.0      0.333333
# 12.0      0.166667
# Name: proportion, dtype: float64

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# total_income          0
# ti_log                0
# dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  145.327973         342.00000
# std        6109.041673        2926.248369   80.051564          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  496.360000         480.00000
#
#        Credit_History  total_income      ti_log
# count      564.000000    614.000000  614.000000
# mean         0.842199   7024.705081    8.666206
# std          0.364878   6458.663872    0.532448
# min          0.000000   1442.000000    7.273786
# 25%          1.000000   4166.000000    8.334712
# 50%          1.000000   5416.500000    8.597205
# 75%          1.000000   7521.750000    8.925549
# max          1.000000  81000.000000   10.530669

# %%
df.Credit_History.fillna('MISSING').value_counts(normalize=True)*100
# Out:
# Credit_History
# 1.0        77.361564
# 0.0        14.495114
# MISSING     8.143322
# Name: proportion, dtype: float64

# %%
df.Credit_History.fillna(0,inplace=True)

# %%
df.Credit_History.fillna('MISSING').value_counts(normalize=True)*100
# Out:
# Credit_History
# 1.0    77.361564
# 0.0    22.638436
# Name: proportion, dtype: float64

# %%
df.Gender.value_counts(normalize=True)*100
# Out:
# Gender
# Male      81.364393
# Female    18.635607
# Name: proportion, dtype: float64

# %%
pd.crosstab(df.Gender.fillna('MISSING'),df.Education)
# Out:
# Education  Graduate  Not Graduate
# Gender
# Female           92            20
# MISSING          12             1
# Male            376           113

# %%
sns.violinplot(x=df.Gender.fillna('MISSING'),y=df.ApplicantIncome)
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>

# %%
pd.crosstab(df.Gender.fillna('MISSING'),df.Married)
# Out:
# Married   No  Yes
# Gender
# Female    80   31
# MISSING    3   10
# Male     130  357

# %%
df.loc[(df.Married=="Yes") & (df.Gender.isnull()),"Gender"]="Male"

# %%
df.Gender.isnull().sum()
# Out:
# 3

# %%
df.Gender.fillna("Male",inplace=True)

# %%
df.Gender.isnull().sum()
# Out:
# 0

# %%
df.Married.value_counts(normalize=True)*100
# Out:
# Married
# Yes    65.139116
# No     34.860884
# Name: proportion, dtype: float64

# %%
pd.crosstab(df.Married.fillna('MISSING'),df.Gender)
# Out:
# Gender   Female  Male
# Married
# MISSING       1     2
# No           80   133
# Yes          31   367

# %%
df.loc[(df.Gender=="Male") & (df.Married.isnull()),"Married"]="Yes"

# %%
df.loc[(df.Gender=="Female") & (df.Married.isnull()),"Married"]="No"

# %%
pd.crosstab(df.Married.fillna('MISSING'),df.Gender)
# Out:
# Gender   Female  Male
# Married
# No           81   133
# Yes          31   369

# %%
sns.violinplot(x=df.Dependents.fillna('MISSING'),y=df.total_income)
# Out:
# <Axes: xlabel='Dependents', ylabel='total_income'>

# %%
df.Dependents.fillna(2,inplace=True)

# %%
sns.violinplot(x=df.Dependents.fillna('MISSING'),y=df.total_income)
# Out:
# <Axes: xlabel='Dependents', ylabel='total_income'>

# %%
pd.crosstab(df.Self_Employed.fillna('MISSING'),df.Education)
# Out:
# Education      Graduate  Not Graduate
# Self_Employed
# MISSING              26             6
# No                  389           111
# Yes                  65            17

# %%
sns.violinplot(x=df.Self_Employed.fillna('MISSING'),y=df.LoanAmount)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='LoanAmount'>

# %%
pd.crosstab(df.Self_Employed.fillna('MISSING'),df.Credit_History)
# Out:
# Credit_History  0.0  1.0
# Self_Employed
# MISSING           7   25
# No              113  387
# Yes              19   63

# %%
sns.scatterplot(x=df.LoanAmount,y=df.ApplicantIncome)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>

# %%
df.groupby(['Gender'])["LoanAmount"].mean()
# Out:
# Gender
# Female    125.746422
# Male      149.746998
# Name: LoanAmount, dtype: float64

# %%
df.groupby(['Education'])["LoanAmount"].mean()
# Out:
# Education
# Graduate        152.679914
# Not Graduate    118.409449
# Name: LoanAmount, dtype: float64

# %%
df.groupby(['Self_Employed'])["LoanAmount"].mean()
# Out:
# Self_Employed
# No     140.951120
# Yes    168.743291
# Name: LoanAmount, dtype: float64

# %%
df.groupby(['Married'])["LoanAmount"].mean()
# Out:
# Married
# No     128.137670
# Yes    154.502073
# Name: LoanAmount, dtype: float64

# %%
df['LoanAmount'].fillna(df.groupby(['Gender'])['LoanAmount'].transform('mean'),inplace=True)

# %%
df.Self_Employed.fillna('Yes',inplace=True)

# %%
df.Loan_Amount_Term.value_counts(normalize=True)*100
# Out:
# Loan_Amount_Term
# 360.0    85.333333
# 180.0     7.333333
# 480.0     2.500000
# 300.0     2.166667
# 240.0     0.666667
# 84.0      0.666667
# 120.0     0.500000
# 60.0      0.333333
# 36.0      0.333333
# 12.0      0.166667
# Name: proportion, dtype: float64

# %%
df.Loan_Amount_Term.fillna(df.Loan_Amount_Term.mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# total_income         0
# ti_log               0
# dtype: int64

# %%
df1=df.copy()

# %%
df2=pd.read_csv('/content/test_lAUu6dG.csv')

# %%
df2["total_income"]=df2["ApplicantIncome"]+df2["CoapplicantIncome"]
df2.total_income
df2.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  total_income
# 0             1.0         Urban          5720
# 1             1.0         Urban          4576
# 2             1.0         Urban          6800
# 3             NaN         Urban          4886
# 4             1.0         Urban          3276

# %%
df2['TI_log']= np.log((df2.total_income))
df2.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  total_income    TI_log
# 0             1.0         Urban          5720  8.651724
# 1             1.0         Urban          4576  8.428581
# 2             1.0         Urban          6800  8.824678
# 3             NaN         Urban          4886  8.494129
# 4             1.0         Urban          3276  8.094378

# %%
p99_2=np.percentile((df2.TI_log),99)
p99_2
# Out:
# 10.173665143824469

# %%
df2['TI_log']= np.where((df2.TI_log)> p99_2, p99_2, (df2.TI_log))
df2.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History  total_income      TI_log
# count      338.000000    367.000000  367.000000
# mean         0.825444   6375.177112    8.613338
# std          0.380150   5199.423594    0.459377
# min          0.000000   1760.000000    7.473069
# 25%          1.000000   4156.000000    8.332308
# 50%          1.000000   5205.000000    8.557375
# 75%          1.000000   6980.000000    8.850789
# max          1.000000  72529.000000   10.173665

# %%
p99_3=np.percentile((df2.LoanAmount.dropna()),99)
p99_3
# Out:
# 371.6999999999996

# %%
df2['LoanAmount']= np.where(df2['LoanAmount']> p99_3, p99_3, df2['LoanAmount'])
df2.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  135.234254        342.537396
# std        4910.685399        2334.232099   56.793978         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  371.700000        480.000000
#
#        Credit_History  total_income      TI_log
# count      338.000000    367.000000  367.000000
# mean         0.825444   6375.177112    8.613338
# std          0.380150   5199.423594    0.459377
# min          0.000000   1760.000000    7.473069
# 25%          1.000000   4156.000000    8.332308
# 50%          1.000000   5205.000000    8.557375
# 75%          1.000000   6980.000000    8.850789
# max          1.000000  72529.000000   10.173665

# %%
df2.Credit_History.fillna('MISSING').value_counts(normalize=True)*100
# Out:
# Credit_History
# 1.0        76.021798
# 0.0        16.076294
# MISSING     7.901907
# Name: proportion, dtype: float64

# %%
df2.Credit_History.fillna(0,inplace=True)

# %%
df2.Credit_History.value_counts(normalize=True)*100
# Out:
# Credit_History
# 1.0    76.021798
# 0.0    23.978202
# Name: proportion, dtype: float64

# %%
df2.loc[(df2.Married=="Yes")&(df2.Gender.isnull()),'Gender']="Male"

# %%
df2.Gender.fillna("Male",inplace=True)

# %%
df2.loc[(df2.Gender=="Male")&(df2.Married.isnull()),'Married']="Yes"

# %%
df2.loc[(df2.Gender=="Female")&(df2.Married.isnull()),'Married']="No"

# %%
df2.Dependents.fillna("2",inplace=True)

# %%
df2.groupby(['Gender'])['LoanAmount'].mean()
# Out:
# Gender
# Female    125.517391
# Male      137.522526
# Name: LoanAmount, dtype: float64

# %%
df2.groupby(['Education'])['LoanAmount'].mean()
# Out:
# Education
# Graduate        140.192832
# Not Graduate    118.566265
# Name: LoanAmount, dtype: float64

# %%
df2.groupby(['Credit_History'])['LoanAmount'].mean()
# Out:
# Credit_History
# 0.0    134.306897
# 1.0    135.527636
# Name: LoanAmount, dtype: float64

# %%
df2.groupby(['Married'])['LoanAmount'].mean()
# Out:
# Married
# No     121.597015
# Yes    143.249123
# Name: LoanAmount, dtype: float64

# %%
df2['LoanAmount'].fillna(df2.groupby('Education')['LoanAmount'].transform('mean'),inplace=True)

# %%
df2.Self_Employed.fillna('Yes',inplace=True)

# %%
df2.Loan_Amount_Term.fillna(df2.Loan_Amount_Term.mode()[0],inplace=True)

# %%
df2_2=df2.drop('Loan_ID',axis=1)

# %%
df1_1=df1.drop('Loan_ID',axis=1)

# %%
X_train=df1_1.drop('Loan_Status',axis=1)

# %%
Y_train=df1_1["Loan_Status"]

# %%
X_test=df2_2.copy()

# %%
X_train=pd.get_dummies(X_train,drop_first=True)

# %%
X_test=pd.get_dummies(X_test,drop_first=True)

# %%
X_train.drop(["total_income","ApplicantIncome","CoapplicantIncome"],axis=1,inplace=True)

# %%
X_test.drop(["total_income","ApplicantIncome","CoapplicantIncome"],axis=1,inplace=True)

# %%
from sklearn.linear_model import LogisticRegression

# %%
X_train.columns.nunique()
# Out:
# 14

# %%
LR=LogisticRegression()
LR.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_test.rename(columns={'TI_log': 'ti_log'}, inplace=True)

X_test['Dependents_0'] = 0

X_test = X_test[X_train.columns]

y_pred = LR.predict(X_test)

# %%
prediction=pd.concat([df2.Loan_ID,pd.DataFrame(y_pred)],axis=1)

# %%
prediction.columns=['Loan_ID','Loan_Status']

# %%
prediction.to_csv('submission.csv',index=False)

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# prompt: give code for random forest using the above data

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


# Split the training data into training and validation sets
X_train_split, X_val_split, Y_train_split, Y_val_split = train_test_split(
    X_train, Y_train, test_size=0.2, random_state=42
)

# Create a Random Forest classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train_split, Y_train_split)

# Make predictions on the validation set
Y_val_pred = rf_model.predict(X_val_split)

# Evaluate the model's performance
accuracy = accuracy_score(Y_val_split, Y_val_pred)
print("Validation Accuracy:", accuracy)

# Make predictions on the test set
y_pred_rf = rf_model.predict(X_test)

# Create a submission file
prediction_rf = pd.concat([df2.Loan_ID, pd.DataFrame(y_pred_rf)], axis=1)
prediction_rf.columns = ['Loan_ID', 'Loan_Status']
prediction_rf.to_csv('submission_rf.csv', index=False)
# Out:
# Validation Accuracy: 0.7235772357723578

# %%
# prompt: Labels in y_true and y_pred should be of the same type. Got y_true=['N' 'Y'] and y_pred=[0 1]. Make sure that the predictions provided by the classifier coincides with the true labels.

# ... (Your existing code) ...

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
Y_train_split = le.fit_transform(Y_train_split) # encode the target variable to numerical values

# NOTE: fit_transform Y_val_split instead of just transform
Y_val_split = le.fit_transform(Y_val_split) # encode the validation target variable to numerical values


# Train the XGBoost model
xgb_model.fit(X_train_split, Y_train_split)

# Make predictions on the validation set
Y_val_pred_xgb = xgb_model.predict(X_val_split)

# Evaluate the model's performance
accuracy_xgb = accuracy_score(Y_val_split, Y_val_pred_xgb)
print("Validation Accuracy (XGBoost):", accuracy_xgb)


# Make predictions on the test set
y_pred_xgb = xgb_model.predict(X_test)

# Convert the predictions to 'Y' and 'N'
y_pred_xgb = le.inverse_transform(y_pred_xgb)


# Create a submission file
prediction_xgb = pd.concat([df2.Loan_ID, pd.DataFrame(y_pred_xgb)], axis=1)
prediction_xgb.columns = ['Loan_ID', 'Loan_Status']
prediction_xgb.to_csv('submission_xgb1.csv', index=False)
# Out:
# Validation Accuracy (XGBoost): 0.6260162601626016
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [08:27:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
